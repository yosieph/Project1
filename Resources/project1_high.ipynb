# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from pathlib import Path
import hvplot.pandas
import requests
import json

# %%
# Load your data into a Pandas DataFrame
df = pd.read_csv("../Resources/projectdata.csv")
df.head()
# Out:
#                Country  Average Temp  \
# 0              Algeria     19.455220
# 1               Angola     25.890110
# 2  Antigua and Barbuda     26.725275
# 3            Argentina     17.916484
# 4              Austria     14.144780
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                               0.16
# 1                                              54.69
# 2                                               0.91
# 3                                              10.74
# 4                                              33.77
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                75.85                            0.00
# 1                                 4.38                            0.00
# 2                                 0.33                            0.00
# 3                                90.56                            7.97
# 4                                16.22                            0.00
#
#    Electricity from renewables (TWh)  Low-carbon electricity (% electricity)  \
# 0                               0.84                                1.095319
# 1                              11.02                               71.558440
# 2                               0.01                                2.941176
# 3                              34.63                               31.991589
# 4                              54.64                               77.109795
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                         16259.0530
# 1                                          3667.4238
# 2                                         33027.5160
# 3                                         20725.1680
# 4                                         48314.2580
#
#    co2 Emissions (metric tons per capita)   Latitude  Longitude  \
# 0                           171250.000000  28.033886   1.659626
# 1                            25209.999080 -11.202692  17.873887
# 2                              519.999981  17.060816 -61.796428
# 3                           168100.006100 -38.416097 -63.616672
# 4                            64769.996640  47.516231  14.550072
#
#    2020 Population
# 0         43451666
# 1         33428485
# 2            92664
# 3         45036032
# 4          8907777

# %%
#import files and read the data
main_data_path = Path("../Resources/projectdata.csv")
main_data = pd.read_csv(main_data_path)
main_data
# Out:
#                   Country  Average Temp  \
# 0                 Algeria     19.455220
# 1                  Angola     25.890110
# 2     Antigua and Barbuda     26.725275
# 3               Argentina     17.916484
# 4                 Austria     14.144780
# ..                    ...           ...
# 98   United Arab Emirates     28.663736
# 99         United Kingdom     10.468681
# 100         United States     15.260440
# 101               Uruguay     16.787637
# 102               Vanuatu     24.085440
#
#      Renewable energy share in the total final energy consumption (%)  \
# 0                                                 0.16
# 1                                                54.69
# 2                                                 0.91
# 3                                                10.74
# 4                                                33.77
# ..                                                 ...
# 98                                                0.67
# 99                                               12.24
# 100                                              10.42
# 101                                              60.76
# 102                                              31.86
#
#      Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                  75.85                            0.00
# 1                                   4.38                            0.00
# 2                                   0.33                            0.00
# 3                                  90.56                            7.97
# 4                                  16.22                            0.00
# ..                                   ...                             ...
# 98                                125.85                            0.00
# 99                                144.99                           56.18
# 100                              2588.21                          809.41
# 101                                 1.89                            0.00
# 102                                 0.05                            0.00
#
#      Electricity from renewables (TWh)  \
# 0                                 0.84
# 1                                11.02
# 2                                 0.01
# 3                                34.63
# 4                                54.64
# ..                                 ...
# 98                                3.80
# 99                              120.48
# 100                             760.76
# 101                              14.16
# 102                               0.02
#
#      Low-carbon electricity (% electricity)  \
# 0                                  1.095319
# 1                                 71.558440
# 2                                  2.941176
# 3                                 31.991589
# 4                                 77.109795
# ..                                      ...
# 98                                 2.930968
# 99                                54.923054
# 100                               37.759180
# 101                               88.224304
# 102                               28.571428
#
#      Primary energy consumption per capita (kWh/person)  \
# 0                                           16259.0530
# 1                                            3667.4238
# 2                                           33027.5160
# 3                                           20725.1680
# 4                                           48314.2580
# ..                                                 ...
# 98                                         134878.3900
# 99                                          32893.7600
# 100                                         79489.0160
# 101                                         19985.0100
# 102                                          3154.4717
#
#      co2 Emissions (metric tons per capita)   Latitude   Longitude  \
# 0                              1.712500e+05  28.033886    1.659626
# 1                              2.521000e+04 -11.202692   17.873887
# 2                              5.200000e+02  17.060816  -61.796428
# 3                              1.681000e+05 -38.416097  -63.616672
# 4                              6.477000e+04  47.516231   14.550072
# ..                                      ...        ...         ...
# 98                             1.888600e+05  23.424076   53.847818
# 99                             3.489200e+05  55.378051   -3.435973
# 100                            4.817720e+06  37.090240  -95.712891
# 101                            6.490000e+03 -32.522779  -55.765835
# 102                            2.100000e+02 -15.376706  166.959158
#
#      2020 Population
# 0           43451666
# 1           33428485
# 2              92664
# 3           45036032
# 4            8907777
# ..               ...
# 98           9287289
# 99          67059474
# 100        335942003
# 101          3429086
# 102           311685
#
# [103 rows x 12 columns]

# %%
# Calculate average CO2 emissions per country
co2_emissions_by_country =main_data.groupby('Country')['co2 Emissions (metric tons per capita)'].mean()
co2_emissions_by_country

# low_co2_emissions_avg = co2_emissions_by_country[co2_emissions_by_country['co2 Emission (metric tons per capita)'] == 'Low']['Low-carbon electricity (% electricity)'].mean()
# high_co2_emissions_avg = co2_emissions_by_country[co2_emissions_by_country['co2 Emission (metric tons per capita'] == 'High']['Low-carbon electricity (% electricity)'].mean()
# Out:
# Country
# Algeria                 1.712500e+05
# Angola                  2.521000e+04
# Antigua and Barbuda     5.200000e+02
# Argentina               1.681000e+05
# Austria                 6.477000e+04
#                             ...
# United Arab Emirates    1.888600e+05
# United Kingdom          3.489200e+05
# United States           4.817720e+06
# Uruguay                 6.490000e+03
# Vanuatu                 2.100000e+02
# Name: co2 Emissions (metric tons per capita), Length: 103, dtype: float64

# %%
# Set your CO2 emissions threshold

threshold = 3.32E-6

main_data['co2-emission catagory'] = ['High' if x > threshold else 'Low' for x in main_data['co2 Emissions (metric tons per capita)']]
main_data
# Out:
#                   Country  Average Temp  \
# 0                 Algeria     19.455220
# 1                  Angola     25.890110
# 2     Antigua and Barbuda     26.725275
# 3               Argentina     17.916484
# 4                 Austria     14.144780
# ..                    ...           ...
# 98   United Arab Emirates     28.663736
# 99         United Kingdom     10.468681
# 100         United States     15.260440
# 101               Uruguay     16.787637
# 102               Vanuatu     24.085440
#
#      Renewable energy share in the total final energy consumption (%)  \
# 0                                                 0.16
# 1                                                54.69
# 2                                                 0.91
# 3                                                10.74
# 4                                                33.77
# ..                                                 ...
# 98                                                0.67
# 99                                               12.24
# 100                                              10.42
# 101                                              60.76
# 102                                              31.86
#
#      Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                  75.85                            0.00
# 1                                   4.38                            0.00
# 2                                   0.33                            0.00
# 3                                  90.56                            7.97
# 4                                  16.22                            0.00
# ..                                   ...                             ...
# 98                                125.85                            0.00
# 99                                144.99                           56.18
# 100                              2588.21                          809.41
# 101                                 1.89                            0.00
# 102                                 0.05                            0.00
#
#      Electricity from renewables (TWh)  \
# 0                                 0.84
# 1                                11.02
# 2                                 0.01
# 3                                34.63
# 4                                54.64
# ..                                 ...
# 98                                3.80
# 99                              120.48
# 100                             760.76
# 101                              14.16
# 102                               0.02
#
#      Low-carbon electricity (% electricity)  \
# 0                                  1.095319
# 1                                 71.558440
# 2                                  2.941176
# 3                                 31.991589
# 4                                 77.109795
# ..                                      ...
# 98                                 2.930968
# 99                                54.923054
# 100                               37.759180
# 101                               88.224304
# 102                               28.571428
#
#      Primary energy consumption per capita (kWh/person)  \
# 0                                           16259.0530
# 1                                            3667.4238
# 2                                           33027.5160
# 3                                           20725.1680
# 4                                           48314.2580
# ..                                                 ...
# 98                                         134878.3900
# 99                                          32893.7600
# 100                                         79489.0160
# 101                                         19985.0100
# 102                                          3154.4717
#
#      co2 Emissions (metric tons per capita)   Latitude   Longitude  \
# 0                              1.712500e+05  28.033886    1.659626
# 1                              2.521000e+04 -11.202692   17.873887
# 2                              5.200000e+02  17.060816  -61.796428
# 3                              1.681000e+05 -38.416097  -63.616672
# 4                              6.477000e+04  47.516231   14.550072
# ..                                      ...        ...         ...
# 98                             1.888600e+05  23.424076   53.847818
# 99                             3.489200e+05  55.378051   -3.435973
# 100                            4.817720e+06  37.090240  -95.712891
# 101                            6.490000e+03 -32.522779  -55.765835
# 102                            2.100000e+02 -15.376706  166.959158
#
#      2020 Population co2-emission catagory
# 0           43451666                  High
# 1           33428485                  High
# 2              92664                  High
# 3           45036032                  High
# 4            8907777                  High
# ..               ...                   ...
# 98           9287289                  High
# 99          67059474                  High
# 100        335942003                  High
# 101          3429086                  High
# 102           311685                  High
#
# [103 rows x 13 columns]

# %%
main_data['co2 Emissions (metric tons per capita)']
# Out:
# 0      1.712500e+05
# 1      2.521000e+04
# 2      5.200000e+02
# 3      1.681000e+05
# 4      6.477000e+04
#            ...
# 98     1.888600e+05
# 99     3.489200e+05
# 100    4.817720e+06
# 101    6.490000e+03
# 102    2.100000e+02
# Name: co2 Emissions (metric tons per capita), Length: 103, dtype: float64

# %%
main_data['co2-emission catagory'].unique()
# Out:
# array(['High'], dtype=object)

# %%
low_co2_avg = main_data[main_data['co2-emission catagory'] == 'Low']['Low-carbon electricity (% electricity)'].mean()
high_co2_avg = main_data[main_data['co2-emission catagory'] == 'High']['Low-carbon electricity (% electricity)'].mean()



# Print the results
print(f'Average Low-Carbon Electricity Percentage for Low CO2 Emissions Countries: {low_co2_avg}')
print(f'Average Low-Carbon Electricity Percentage for High CO2 Emissions Countries: {high_co2_avg}')
# Out:
# Average Low-Carbon Electricity Percentage for Low CO2 Emissions Countries: nan
# Average Low-Carbon Electricity Percentage for High CO2 Emissions Countries: 35.25776505116505

# %%
# Create a scatter plot
plt.scatter(df['co2 Emissions (metric tons per capita)'], df['Low-carbon electricity (% electricity)'])
plt.xlabel('CO2 Emissions')
plt.ylabel('Low-Carbon Electricity Use')
plt.title('Relationship between CO2 Emissions and Low-Carbon Electricity Use')
# Out:
# Text(0.5, 1.0, 'Relationship between CO2 Emissions and Low-Carbon Electricity Use')
