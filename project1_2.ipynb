# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress
from pathlib import Path
import hvplot.pandas
import requests
import json
import warnings
warnings.filterwarnings('ignore')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load your data into a Pandas DataFrame
main_data_path = Path("Resources/projectdata.csv")
main_data = pd.read_csv(main_data_path)
main_data
# Out:
#      Unnamed: 0               Country  Average Temp  \
# 0             0               Algeria     19.455220
# 1             1                Angola     25.890110
# 2             2   Antigua and Barbuda     26.725275
# 3             3             Argentina     17.916484
# 4             4               Austria     14.144780
# ..          ...                   ...           ...
# 98           98  United Arab Emirates     28.663736
# 99           99        United Kingdom     10.468681
# 100         100         United States     15.260440
# 101         101               Uruguay     16.787637
# 102         102               Vanuatu     24.085440
#
#      Renewable energy share in the total final energy consumption (%)  \
# 0                                                 0.16
# 1                                                54.69
# 2                                                 0.91
# 3                                                10.74
# 4                                                33.77
# ..                                                 ...
# 98                                                0.67
# 99                                               12.24
# 100                                              10.42
# 101                                              60.76
# 102                                              31.86
#
#      Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                  75.85                            0.00
# 1                                   4.38                            0.00
# 2                                   0.33                            0.00
# 3                                  90.56                            7.97
# 4                                  16.22                            0.00
# ..                                   ...                             ...
# 98                                125.85                            0.00
# 99                                144.99                           56.18
# 100                              2588.21                          809.41
# 101                                 1.89                            0.00
# 102                                 0.05                            0.00
#
#      Electricity from renewables (TWh)  \
# 0                                 0.84
# 1                                11.02
# 2                                 0.01
# 3                                34.63
# 4                                54.64
# ..                                 ...
# 98                                3.80
# 99                              120.48
# 100                             760.76
# 101                              14.16
# 102                               0.02
#
#      Low-carbon electricity (% electricity)  \
# 0                                  1.095319
# 1                                 71.558440
# 2                                  2.941176
# 3                                 31.991589
# 4                                 77.109795
# ..                                      ...
# 98                                 2.930968
# 99                                54.923054
# 100                               37.759180
# 101                               88.224304
# 102                               28.571428
#
#      Primary energy consumption per capita (kWh/person)  \
# 0                                           16259.0530
# 1                                            3667.4238
# 2                                           33027.5160
# 3                                           20725.1680
# 4                                           48314.2580
# ..                                                 ...
# 98                                         134878.3900
# 99                                          32893.7600
# 100                                         79489.0160
# 101                                         19985.0100
# 102                                          3154.4717
#
#      co2 Emissions (metric tons per capita)   Latitude   Longitude  \
# 0                                  171250.0  28.033886    1.659626
# 1                                   25210.0 -11.202692   17.873887
# 2                                     520.0  17.060816  -61.796428
# 3                                  168100.0 -38.416097  -63.616672
# 4                                   64770.0  47.516231   14.550072
# ..                                      ...        ...         ...
# 98                                 188860.0  23.424076   53.847818
# 99                                 348920.0  55.378051   -3.435973
# 100                               4817720.0  37.090240  -95.712891
# 101                                  6490.0 -32.522779  -55.765835
# 102                                   210.0 -15.376706  166.959158
#
#      2020 Population  Renewable energy consumption per capita (kWh/person)
# 0           43451666                                          26.014485
# 1           33428485                                        2005.714076
# 2              92664                                         300.550396
# 3           45036032                                        2225.883043
# 4            8907777                                       16315.724927
# ..               ...                                                ...
# 98           9287289                                         903.685213
# 99          67059474                                        4026.196224
# 100        335942003                                        8282.755467
# 101          3429086                                       12142.892076
# 102           311685                                        1005.014684
#
# [103 rows x 14 columns]

# %%
# low_co2_emissions_avg = co2_emissions_by_country[co2_emissions_by_country['co2 Emission (metric tons per capita)'] == 'Low']['Low-carbon electricity (% electricity)'].mean()
# high_co2_emissions_avg = co2_emissions_by_country[co2_emissions_by_country['co2 Emission (metric tons per capita'] == 'High']['Low-carbon electricity (% electricity)'].mean()
# Out:
# Country
# Algeria                  171250.0
# Angola                    25210.0
# Antigua and Barbuda         520.0
# Argentina                168100.0
# Austria                   64770.0
#                           ...
# United Arab Emirates     188860.0
# United Kingdom           348920.0
# United States           4817720.0
# Uruguay                    6490.0
# Vanuatu                     210.0
# Name: co2 Emissions (metric tons per capita), Length: 103, dtype: float64

# %%
# Set your CO2 emissions threshold

threshold = 33200000000

main_data['co2-emission catagory'] = ['High' if x > threshold else 'Low' for x in main_data['co2 Emissions (metric tons per capita)']]
main_data
# Out:
#      Unnamed: 0               Country  Average Temp  \
# 0             0               Algeria     19.455220
# 1             1                Angola     25.890110
# 2             2   Antigua and Barbuda     26.725275
# 3             3             Argentina     17.916484
# 4             4               Austria     14.144780
# ..          ...                   ...           ...
# 98           98  United Arab Emirates     28.663736
# 99           99        United Kingdom     10.468681
# 100         100         United States     15.260440
# 101         101               Uruguay     16.787637
# 102         102               Vanuatu     24.085440
#
#      Renewable energy share in the total final energy consumption (%)  \
# 0                                                 0.16
# 1                                                54.69
# 2                                                 0.91
# 3                                                10.74
# 4                                                33.77
# ..                                                 ...
# 98                                                0.67
# 99                                               12.24
# 100                                              10.42
# 101                                              60.76
# 102                                              31.86
#
#      Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                  75.85                            0.00
# 1                                   4.38                            0.00
# 2                                   0.33                            0.00
# 3                                  90.56                            7.97
# 4                                  16.22                            0.00
# ..                                   ...                             ...
# 98                                125.85                            0.00
# 99                                144.99                           56.18
# 100                              2588.21                          809.41
# 101                                 1.89                            0.00
# 102                                 0.05                            0.00
#
#      Electricity from renewables (TWh)  \
# 0                                 0.84
# 1                                11.02
# 2                                 0.01
# 3                                34.63
# 4                                54.64
# ..                                 ...
# 98                                3.80
# 99                              120.48
# 100                             760.76
# 101                              14.16
# 102                               0.02
#
#      Low-carbon electricity (% electricity)  \
# 0                                  1.095319
# 1                                 71.558440
# 2                                  2.941176
# 3                                 31.991589
# 4                                 77.109795
# ..                                      ...
# 98                                 2.930968
# 99                                54.923054
# 100                               37.759180
# 101                               88.224304
# 102                               28.571428
#
#      Primary energy consumption per capita (kWh/person)  \
# 0                                           16259.0530
# 1                                            3667.4238
# 2                                           33027.5160
# 3                                           20725.1680
# 4                                           48314.2580
# ..                                                 ...
# 98                                         134878.3900
# 99                                          32893.7600
# 100                                         79489.0160
# 101                                         19985.0100
# 102                                          3154.4717
#
#      co2 Emissions (metric tons per capita)   Latitude   Longitude  \
# 0                                  171250.0  28.033886    1.659626
# 1                                   25210.0 -11.202692   17.873887
# 2                                     520.0  17.060816  -61.796428
# 3                                  168100.0 -38.416097  -63.616672
# 4                                   64770.0  47.516231   14.550072
# ..                                      ...        ...         ...
# 98                                 188860.0  23.424076   53.847818
# 99                                 348920.0  55.378051   -3.435973
# 100                               4817720.0  37.090240  -95.712891
# 101                                  6490.0 -32.522779  -55.765835
# 102                                   210.0 -15.376706  166.959158
#
#      2020 Population  Renewable energy consumption per capita (kWh/person)  \
# 0           43451666                                          26.014485
# 1           33428485                                        2005.714076
# 2              92664                                         300.550396
# 3           45036032                                        2225.883043
# 4            8907777                                       16315.724927
# ..               ...                                                ...
# 98           9287289                                         903.685213
# 99          67059474                                        4026.196224
# 100        335942003                                        8282.755467
# 101          3429086                                       12142.892076
# 102           311685                                        1005.014684
#
#     co2-emission catagory
# 0                     Low
# 1                     Low
# 2                     Low
# 3                     Low
# 4                     Low
# ..                    ...
# 98                    Low
# 99                    Low
# 100                   Low
# 101                   Low
# 102                   Low
#
# [103 rows x 15 columns]

# %%
main_data['co2 Emissions (metric tons per capita)']
# Out:
# 0       171250.0
# 1        25210.0
# 2          520.0
# 3       168100.0
# 4        64770.0
#          ...
# 98      188860.0
# 99      348920.0
# 100    4817720.0
# 101       6490.0
# 102        210.0
# Name: co2 Emissions (metric tons per capita), Length: 103, dtype: float64

# %%
main_data['co2-emission catagory'].unique()
# Out:
# array(['Low'], dtype=object)

# %%
low_co2_avg = main_data[main_data['co2-emission catagory'] == 'Low']['Low-carbon electricity (% electricity)'].mean()
high_co2_avg = main_data[main_data['co2-emission catagory'] == 'High']['Low-carbon electricity (% electricity)'].mean()



# Print the results
print(f'Average Low-Carbon Electricity Percentage for Low CO2 Emissions Countries: {low_co2_avg}')
print(f'Average Low-Carbon Electricity Percentage for High CO2 Emissions Countries: {high_co2_avg}')
# Out:
# Average Low-Carbon Electricity Percentage for Low CO2 Emissions Countries: 35.25776505116505
# Average Low-Carbon Electricity Percentage for High CO2 Emissions Countries: nan

# %%
# Set your CO2 emissions threshold

threshold = 4.2637648

main_data['co2-emission catagory'] = ['High' if x > threshold else 'Low' for x in main_data['co2 Emissions (metric tons per capita)']]
main_data
# Out:
#      Unnamed: 0               Country  Average Temp  \
# 0             0               Algeria     19.455220
# 1             1                Angola     25.890110
# 2             2   Antigua and Barbuda     26.725275
# 3             3             Argentina     17.916484
# 4             4               Austria     14.144780
# ..          ...                   ...           ...
# 98           98  United Arab Emirates     28.663736
# 99           99        United Kingdom     10.468681
# 100         100         United States     15.260440
# 101         101               Uruguay     16.787637
# 102         102               Vanuatu     24.085440
#
#      Renewable energy share in the total final energy consumption (%)  \
# 0                                                 0.16
# 1                                                54.69
# 2                                                 0.91
# 3                                                10.74
# 4                                                33.77
# ..                                                 ...
# 98                                                0.67
# 99                                               12.24
# 100                                              10.42
# 101                                              60.76
# 102                                              31.86
#
#      Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                  75.85                            0.00
# 1                                   4.38                            0.00
# 2                                   0.33                            0.00
# 3                                  90.56                            7.97
# 4                                  16.22                            0.00
# ..                                   ...                             ...
# 98                                125.85                            0.00
# 99                                144.99                           56.18
# 100                              2588.21                          809.41
# 101                                 1.89                            0.00
# 102                                 0.05                            0.00
#
#      Electricity from renewables (TWh)  \
# 0                                 0.84
# 1                                11.02
# 2                                 0.01
# 3                                34.63
# 4                                54.64
# ..                                 ...
# 98                                3.80
# 99                              120.48
# 100                             760.76
# 101                              14.16
# 102                               0.02
#
#      Low-carbon electricity (% electricity)  \
# 0                                  1.095319
# 1                                 71.558440
# 2                                  2.941176
# 3                                 31.991589
# 4                                 77.109795
# ..                                      ...
# 98                                 2.930968
# 99                                54.923054
# 100                               37.759180
# 101                               88.224304
# 102                               28.571428
#
#      Primary energy consumption per capita (kWh/person)  \
# 0                                           16259.0530
# 1                                            3667.4238
# 2                                           33027.5160
# 3                                           20725.1680
# 4                                           48314.2580
# ..                                                 ...
# 98                                         134878.3900
# 99                                          32893.7600
# 100                                         79489.0160
# 101                                         19985.0100
# 102                                          3154.4717
#
#      co2 Emissions (metric tons per capita)   Latitude   Longitude  \
# 0                                  171250.0  28.033886    1.659626
# 1                                   25210.0 -11.202692   17.873887
# 2                                     520.0  17.060816  -61.796428
# 3                                  168100.0 -38.416097  -63.616672
# 4                                   64770.0  47.516231   14.550072
# ..                                      ...        ...         ...
# 98                                 188860.0  23.424076   53.847818
# 99                                 348920.0  55.378051   -3.435973
# 100                               4817720.0  37.090240  -95.712891
# 101                                  6490.0 -32.522779  -55.765835
# 102                                   210.0 -15.376706  166.959158
#
#      2020 Population  Renewable energy consumption per capita (kWh/person)  \
# 0           43451666                                          26.014485
# 1           33428485                                        2005.714076
# 2              92664                                         300.550396
# 3           45036032                                        2225.883043
# 4            8907777                                       16315.724927
# ..               ...                                                ...
# 98           9287289                                         903.685213
# 99          67059474                                        4026.196224
# 100        335942003                                        8282.755467
# 101          3429086                                       12142.892076
# 102           311685                                        1005.014684
#
#     co2-emission catagory
# 0                    High
# 1                    High
# 2                    High
# 3                    High
# 4                    High
# ..                    ...
# 98                   High
# 99                   High
# 100                  High
# 101                  High
# 102                  High
#
# [103 rows x 15 columns]

# %%
# Set x axis and tick locations
x_axis = np.arange(len(main_data))
tick_locations = [value for value in x_axis]

# %%
plt.figure(figsize=(20,4))
plt.bar(x_axis, main_data["Low-carbon electricity (% electricity)"], color='r', alpha=0.5, align="center" )
plt.xticks(tick_locations, main_data["Country"], rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x241bfe64550>,
#   <matplotlib.axis.XTick at 0x241bfe64520>,
#   <matplotlib.axis.XTick at 0x241bfde7c70>,
#   <matplotlib.axis.XTick at 0x241c0634be0>,
#   <matplotlib.axis.XTick at 0x241c0635690>,
#   <matplotlib.axis.XTick at 0x241c0636140>,
#   <matplotlib.axis.XTick at 0x241c0636bf0>,
#   <matplotlib.axis.XTick at 0x241c06376a0>,
#   <matplotlib.axis.XTick at 0x241c06358a0>,
#   <matplotlib.axis.XTick at 0x241c0637d60>,
#   <matplotlib.axis.XTick at 0x241c0650bb0>,
#   <matplotlib.axis.XTick at 0x241c0651660>,
#   <matplotlib.axis.XTick at 0x241c0637010>,
#   <matplotlib.axis.XTick at 0x241c0651ff0>,
#   <matplotlib.axis.XTick at 0x241c0652aa0>,
#   <matplotlib.axis.XTick at 0x241c0653550>,
#   <matplotlib.axis.XTick at 0x241c0653ca0>,
#   <matplotlib.axis.XTick at 0x241c06525f0>,
#   <matplotlib.axis.XTick at 0x241c066ca60>,
#   <matplotlib.axis.XTick at 0x241c066d510>,
#   <matplotlib.axis.XTick at 0x241c066dfc0>,
#   <matplotlib.axis.XTick at 0x241c066ea70>,
#   <matplotlib.axis.XTick at 0x241c066d960>,
#   <matplotlib.axis.XTick at 0x241c066f370>,
#   <matplotlib.axis.XTick at 0x241c066fe20>,
#   <matplotlib.axis.XTick at 0x241c0684940>,
#   <matplotlib.axis.XTick at 0x241c06853f0>,
#   <matplotlib.axis.XTick at 0x241c0684d90>,
#   <matplotlib.axis.XTick at 0x241c0685c60>,
#   <matplotlib.axis.XTick at 0x241c0686710>,
#   <matplotlib.axis.XTick at 0x241c06871c0>,
#   <matplotlib.axis.XTick at 0x241c066d0f0>,
#   <matplotlib.axis.XTick at 0x241c0687ac0>,
#   <matplotlib.axis.XTick at 0x241c06a05b0>,
#   <matplotlib.axis.XTick at 0x241c06a1060>,
#   <matplotlib.axis.XTick at 0x241c06a1b10>,
#   <matplotlib.axis.XTick at 0x241c06860b0>,
#   <matplotlib.axis.XTick at 0x241c06a2530>,
#   <matplotlib.axis.XTick at 0x241c06a2fe0>,
#   <matplotlib.axis.XTick at 0x241c06a3a90>,
#   <matplotlib.axis.XTick at 0x241c06b8580>,
#   <matplotlib.axis.XTick at 0x241c06a2170>,
#   <matplotlib.axis.XTick at 0x241c06b8e80>,
#   <matplotlib.axis.XTick at 0x241c06b9930>,
#   <matplotlib.axis.XTick at 0x241c06ba3e0>,
#   <matplotlib.axis.XTick at 0x241c06bae90>,
#   <matplotlib.axis.XTick at 0x241c06b95a0>,
#   <matplotlib.axis.XTick at 0x241c06bb700>,
#   <matplotlib.axis.XTick at 0x241c06d81f0>,
#   <matplotlib.axis.XTick at 0x241c06d8ca0>,
#   <matplotlib.axis.XTick at 0x241c06bb070>,
#   <matplotlib.axis.XTick at 0x241c06d95a0>,
#   <matplotlib.axis.XTick at 0x241c06da050>,
#   <matplotlib.axis.XTick at 0x241c06dab00>,
#   <matplotlib.axis.XTick at 0x241c06db5b0>,
#   <matplotlib.axis.XTick at 0x241c06875e0>,
#   <matplotlib.axis.XTick at 0x241c06da590>,
#   <matplotlib.axis.XTick at 0x241c06dbd90>,
#   <matplotlib.axis.XTick at 0x241c06fc880>,
#   <matplotlib.axis.XTick at 0x241c06fd330>,
#   <matplotlib.axis.XTick at 0x241c06a0ca0>,
#   <matplotlib.axis.XTick at 0x241c06fdc30>,
#   <matplotlib.axis.XTick at 0x241c06fe6e0>,
#   <matplotlib.axis.XTick at 0x241c06ff190>,
#   <matplotlib.axis.XTick at 0x241c06ffc40>,
#   <matplotlib.axis.XTick at 0x241c06fe2c0>,
#   <matplotlib.axis.XTick at 0x241c070c4f0>,
#   <matplotlib.axis.XTick at 0x241c070cfa0>,
#   <matplotlib.axis.XTick at 0x241c070da50>,
#   <matplotlib.axis.XTick at 0x241c06fcb80>,
#   <matplotlib.axis.XTick at 0x241c070ca30>,
#   <matplotlib.axis.XTick at 0x241c070ed70>,
#   <matplotlib.axis.XTick at 0x241c070f820>,
#   <matplotlib.axis.XTick at 0x241c0730310>,
#   <matplotlib.axis.XTick at 0x241c070f190>,
#   <matplotlib.axis.XTick at 0x241c0730c10>,
#   <matplotlib.axis.XTick at 0x241c07316c0>,
#   <matplotlib.axis.XTick at 0x241c07321a0>,
#   <matplotlib.axis.XTick at 0x241c0732c50>,
#   <matplotlib.axis.XTick at 0x241c0731cf0>,
#   <matplotlib.axis.XTick at 0x241c0733670>,
#   <matplotlib.axis.XTick at 0x241c0733dc0>,
#   <matplotlib.axis.XTick at 0x241c0744c10>,
#   <matplotlib.axis.XTick at 0x241c07456c0>,
#   <matplotlib.axis.XTick at 0x241c0731330>,
#   <matplotlib.axis.XTick at 0x241c0745fc0>,
#   <matplotlib.axis.XTick at 0x241c0746a70>,
#   <matplotlib.axis.XTick at 0x241c0747520>,
#   <matplotlib.axis.XTick at 0x241c0747fd0>,
#   <matplotlib.axis.XTick at 0x241c07443d0>,
#   <matplotlib.axis.XTick at 0x241c075c880>,
#   <matplotlib.axis.XTick at 0x241c075d330>,
#   <matplotlib.axis.XTick at 0x241c075dde0>,
#   <matplotlib.axis.XTick at 0x241c0746fb0>,
#   <matplotlib.axis.XTick at 0x241c075e6e0>,
#   <matplotlib.axis.XTick at 0x241c075f190>,
#   <matplotlib.axis.XTick at 0x241c075fc40>,
#   <matplotlib.axis.XTick at 0x241c0774730>,
#   <matplotlib.axis.XTick at 0x241c075e9e0>,
#   <matplotlib.axis.XTick at 0x241c0775150>,
#   <matplotlib.axis.XTick at 0x241c0775c00>,
#   <matplotlib.axis.XTick at 0x241c07766b0>,
#   <matplotlib.axis.XTick at 0x241c0777160>],
#  [Text(0, 0, 'Algeria'),
#   Text(1, 0, 'Angola'),
#   Text(2, 0, 'Antigua and Barbuda'),
#   Text(3, 0, 'Argentina'),
#   Text(4, 0, 'Austria'),
#   Text(5, 0, 'Azerbaijan'),
#   Text(6, 0, 'Bahrain'),
#   Text(7, 0, 'Bangladesh'),
#   Text(8, 0, 'Barbados'),
#   Text(9, 0, 'Belarus'),
#   Text(10, 0, 'Belgium'),
#   Text(11, 0, 'Benin'),
#   Text(12, 0, 'Burkina Faso'),
#   Text(13, 0, 'Cambodia'),
#   Text(14, 0, 'Canada'),
#   Text(15, 0, 'Central African Republic'),
#   Text(16, 0, 'Chad'),
#   Text(17, 0, 'China'),
#   Text(18, 0, 'Comoros'),
#   Text(19, 0, 'Croatia'),
#   Text(20, 0, 'Cuba'),
#   Text(21, 0, 'Denmark'),
#   Text(22, 0, 'Djibouti'),
#   Text(23, 0, 'Dominican Republic'),
#   Text(24, 0, 'El Salvador'),
#   Text(25, 0, 'Equatorial Guinea'),
#   Text(26, 0, 'Estonia'),
#   Text(27, 0, 'Fiji'),
#   Text(28, 0, 'Finland'),
#   Text(29, 0, 'France'),
#   Text(30, 0, 'Gabon'),
#   Text(31, 0, 'Germany'),
#   Text(32, 0, 'Ghana'),
#   Text(33, 0, 'Greece'),
#   Text(34, 0, 'Grenada'),
#   Text(35, 0, 'Guinea'),
#   Text(36, 0, 'Guinea-Bissau'),
#   Text(37, 0, 'Guyana'),
#   Text(38, 0, 'Hungary'),
#   Text(39, 0, 'Iceland'),
#   Text(40, 0, 'India'),
#   Text(41, 0, 'Iraq'),
#   Text(42, 0, 'Ireland'),
#   Text(43, 0, 'Israel'),
#   Text(44, 0, 'Italy'),
#   Text(45, 0, 'Jamaica'),
#   Text(46, 0, 'Japan'),
#   Text(47, 0, 'Kiribati'),
#   Text(48, 0, 'Kuwait'),
#   Text(49, 0, 'Latvia'),
#   Text(50, 0, 'Lebanon'),
#   Text(51, 0, 'Libya'),
#   Text(52, 0, 'Lithuania'),
#   Text(53, 0, 'Luxembourg'),
#   Text(54, 0, 'Maldives'),
#   Text(55, 0, 'Mali'),
#   Text(56, 0, 'Malta'),
#   Text(57, 0, 'Mauritania'),
#   Text(58, 0, 'Mauritius'),
#   Text(59, 0, 'Montenegro'),
#   Text(60, 0, 'Morocco'),
#   Text(61, 0, 'Mozambique'),
#   Text(62, 0, 'Nauru'),
#   Text(63, 0, 'Netherlands'),
#   Text(64, 0, 'New Zealand'),
#   Text(65, 0, 'Nicaragua'),
#   Text(66, 0, 'Niger'),
#   Text(67, 0, 'Norway'),
#   Text(68, 0, 'Oman'),
#   Text(69, 0, 'Panama'),
#   Text(70, 0, 'Papua New Guinea'),
#   Text(71, 0, 'Paraguay'),
#   Text(72, 0, 'Peru'),
#   Text(73, 0, 'Philippines'),
#   Text(74, 0, 'Poland'),
#   Text(75, 0, 'Portugal'),
#   Text(76, 0, 'Qatar'),
#   Text(77, 0, 'Romania'),
#   Text(78, 0, 'Samoa'),
#   Text(79, 0, 'Senegal'),
#   Text(80, 0, 'Serbia'),
#   Text(81, 0, 'Seychelles'),
#   Text(82, 0, 'Sierra Leone'),
#   Text(83, 0, 'Singapore'),
#   Text(84, 0, 'Slovenia'),
#   Text(85, 0, 'Solomon Islands'),
#   Text(86, 0, 'Somalia'),
#   Text(87, 0, 'Spain'),
#   Text(88, 0, 'Sri Lanka'),
#   Text(89, 0, 'Sudan'),
#   Text(90, 0, 'Sweden'),
#   Text(91, 0, 'Thailand'),
#   Text(92, 0, 'Togo'),
#   Text(93, 0, 'Tonga'),
#   Text(94, 0, 'Trinidad and Tobago'),
#   Text(95, 0, 'Tunisia'),
#   Text(96, 0, 'Turkmenistan'),
#   Text(97, 0, 'Ukraine'),
#   Text(98, 0, 'United Arab Emirates'),
#   Text(99, 0, 'United Kingdom'),
#   Text(100, 0, 'United States'),
#   Text(101, 0, 'Uruguay'),
#   Text(102, 0, 'Vanuatu')])

# %%
plt.figure(figsize=(15,6))
plt.bar(df['Low-carbon electricity (% electricity)'],df['co2 Emissions (metric tons per capita)'] ,width=10 ,color=['blue','green'])
plt.xlabel('CO2 Emissions')
plt.ylabel('Low-Carbon Electricity Use')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\danik\OneDrive\Desktop\Project 1\Project1\project1_2.ipynb Cell 12 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/danik/OneDrive/Desktop/Project%201/Project1/project1_2.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> plt.figure(figsize=(15,6))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/danik/OneDrive/Desktop/Project%201/Project1/project1_2.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> plt.bar(df['Low-carbon electricity (% electricity)'],df['co2 Emissions (metric tons per capita)'] ,width=10 ,color=['blue','green'])
#       <a href='vscode-notebook-cell:/c%3A/Users/danik/OneDrive/Desktop/Project%201/Project1/project1_2.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> plt.xlabel('CO2 Emissions')
#       <a href='vscode-notebook-cell:/c%3A/Users/danik/OneDrive/Desktop/Project%201/Project1/project1_2.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> plt.ylabel('Low-Carbon Electricity Use')
#
# NameError: name 'df' is not defined

# %%
main_data.values

# %%
main_data.index

# %%
# Create a scatter plot
plt.scatter(df['co2 Emissions (metric tons per capita)'], df['Low-carbon electricity (% electricity)'])
plt.xlabel('CO2 Emissions')
plt.ylabel('Low-Carbon Electricity Use')
plt.title('Relationship between CO2 Emissions and Low-Carbon Electricity Use')

# %%
category_means = main_data.groupby('co2 Emissions (metric tons per capita)')['Low-carbon electricity (% electricity)'].mean()
category_means

# %%
y=category_means.index
y

# %%
help(plt.bar)

# %%
x=category_means.values
x

# %%
plt.bar(category_means.values, category_means.index)
plt.show()

# %%
print(type (category_means))

# %%
# Create a bar graph

plt.figure(figsize=(10,6))
plt.bar(x,y , width=10 ,color=['blue','red'])
plt.xlabel('CO2 Emissions Category')
plt.ylabel('Average Low-Carbon Electricity Percentage')
plt.title('Low-Carbon Electricity Usage by CO2 Emissions Category')





plt.show()

# %%
# Set your CO2 emissions threshold

threshold = 4.2637648

main_data['co2-emission catagory2'] = ['High' if x < threshold else 'Low' for x in main_data['co2 Emissions (metric tons per capita)']]
main_data

# %%
plt.figure(figsize=(15,6))
plt.bar(df['Low-carbon electricity (% electricity)'],df['co2 Emissions (metric tons per capita)'] ,width=10 ,color=['blue','green'])
plt.xlabel('CO2 Emissions')
plt.ylabel('low-Carbon Elericity')
plt.show()
